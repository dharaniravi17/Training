# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
np.random.seed(42)
data = {
    'Region': np.random.choice(['North', 'South', 'East', 'West'], 200),
    'Sales': np.random.normal(50000, 12000, 200),
    'Month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 200)
}
df = pd.DataFrame(data)

north_sales = df[df['Region'] == 'North']['Sales']
south_sales = df[df['Region'] == 'South']['Sales']
t_stat, p_value = stats.ttest_ind(north_sales, south_sales, equal_var=False)
print(f"T-statistic: {t_stat:.2f}, P-value: {p_value:.4f}")
if p_value < 0.05:
    print("Reject the null hypothesis: Significant difference in sales.")
else:
    print("Fail to reject the null hypothesis: No significant difference in sales.")

plt.figure(figsize=(8, 5))
sns.boxplot(x='Region', y='Sales', data=df)
plt.title('Sales Distribution by Region')
plt.show()
# Out:
# T-statistic: 2.36, P-value: 0.0203
# Reject the null hypothesis: Significant difference in sales.
