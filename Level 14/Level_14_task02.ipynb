# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_wine

data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df["target"] = data.target  

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df.drop(columns=["target"]))
y = df["target"]  

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

explained_variance = pca.explained_variance_ratio_
total_variance = np.sum(explained_variance)

print(f"🔹 Explained Variance by PCA Components: {explained_variance}")
print(f"🔹 Total Variance Retained: {total_variance:.4f}")

plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap="viridis", alpha=0.7)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Projection of Wine Dataset (2D)")
plt.colorbar(label="Target Class")
plt.grid(True)
plt.show()
# Out:
# 🔹 Explained Variance by PCA Components: [0.36198848 0.1920749 ]
# 🔹 Total Variance Retained: 0.5541
